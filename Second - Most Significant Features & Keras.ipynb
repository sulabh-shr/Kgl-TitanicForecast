# %% [markdown]
# # Importing Jupyter modules

# %%
from IPython.display import display

# %% [markdown]
# # Importing Modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading data
# Put both train and test csv files from Kaggle inside **data** folder which in turn should be in the folder where your **notebook resides**.

# %%
train_df = pd.read_csv("data/train.csv")
train_df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
test_df = pd.read_csv("data/test.csv")
test_df.head(2)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S

# %% [markdown]
# # Check row details of the data frames

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
to_drop = ["PassengerId", "Name", "Ticket", "Cabin", "Fare"]

# %%
train2 = train_df.drop(to_drop, axis=1)
test2 = test_df.drop(to_drop, axis=1)

# %%
train2.head(2)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0         0       3    male  22.0      1      0        S
# 1         1       1  female  38.0      1      0        C

# %%
test2.head(2)
# Out:
#    Pclass     Sex   Age  SibSp  Parch Embarked
# 0       3    male  34.5      0      0        Q
# 1       3  female  47.0      1      0        S

# %% [markdown]
# # Check Null Embarked

# %%
train2[train2["Embarked"].isnull()==True]
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 61          1       1  female  38.0      0      0      NaN
# 829         1       1  female  62.0      0      0      NaN

# %% [markdown]
# # Fill with highest embarked

# %%
most_embarked = train2["Embarked"].mode()[0]
most_embarked
# Out:
# 'S'

# %%
train2["Embarked"] = train2["Embarked"].fillna(most_embarked)

# %% [markdown]
# # Check Null Embarked again

# %%
train2[train2["Embarked"].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Sex, Age, SibSp, Parch, Embarked]
# Index: []

# %% [markdown]
# # Check Null Age

# %%
train2[train2["Age"].isnull()==True]
# Out:
#      Survived  Pclass     Sex  Age  SibSp  Parch Embarked
# 5           0       3    male  NaN      0      0        Q
# 17          1       2    male  NaN      0      0        S
# 19          1       3  female  NaN      0      0        C
# 26          0       3    male  NaN      0      0        C
# 28          1       3  female  NaN      0      0        Q
# 29          0       3    male  NaN      0      0        S
# 31          1       1  female  NaN      1      0        C
# 32          1       3  female  NaN      0      0        Q
# 36          1       3    male  NaN      0      0        C
# 42          0       3    male  NaN      0      0        C
# 45          0       3    male  NaN      0      0        S
# 46          0       3    male  NaN      1      0        Q
# 47          1       3  female  NaN      0      0        Q
# 48          0       3    male  NaN      2      0        C
# 55          1       1    male  NaN      0      0        S
# 64          0       1    male  NaN      0      0        C
# 65          1       3    male  NaN      1      1        C
# 76          0       3    male  NaN      0      0        S
# 77          0       3    male  NaN      0      0        S
# 82          1       3  female  NaN      0      0        Q
# 87          0       3    male  NaN      0      0        S
# 95          0       3    male  NaN      0      0        S
# 101         0       3    male  NaN      0      0        S
# 107         1       3    male  NaN      0      0        S
# 109         1       3  female  NaN      1      0        Q
# 121         0       3    male  NaN      0      0        S
# 126         0       3    male  NaN      0      0        Q
# 128         1       3  female  NaN      1      1        C
# 140         0       3  female  NaN      0      2        C
# 154         0       3    male  NaN      0      0        S
# ..        ...     ...     ...  ...    ...    ...      ...
# 718         0       3    male  NaN      0      0        Q
# 727         1       3  female  NaN      0      0        Q
# 732         0       2    male  NaN      0      0        S
# 738         0       3    male  NaN      0      0        S
# 739         0       3    male  NaN      0      0        S
# 740         1       1    male  NaN      0      0        S
# 760         0       3    male  NaN      0      0        S
# 766         0       1    male  NaN      0      0        C
# 768         0       3    male  NaN      1      0        Q
# 773         0       3    male  NaN      0      0        C
# 776         0       3    male  NaN      0      0        Q
# 778         0       3    male  NaN      0      0        Q
# 783         0       3    male  NaN      1      2        S
# 790         0       3    male  NaN      0      0        Q
# 792         0       3  female  NaN      8      2        S
# 793         0       1    male  NaN      0      0        C
# 815         0       1    male  NaN      0      0        S
# 825         0       3    male  NaN      0      0        Q
# 826         0       3    male  NaN      0      0        S
# 828         1       3    male  NaN      0      0        Q
# 832         0       3    male  NaN      0      0        C
# 837         0       3    male  NaN      0      0        S
# 839         1       1    male  NaN      0      0        C
# 846         0       3    male  NaN      8      2        S
# 849         1       1  female  NaN      1      0        C
# 859         0       3    male  NaN      0      0        C
# 863         0       3  female  NaN      8      2        S
# 868         0       3    male  NaN      0      0        S
# 878         0       3    male  NaN      0      0        S
# 888         0       3  female  NaN      1      2        S
#
# [177 rows x 7 columns]

# %%
test2[test2["Age"].isnull()==True]
# Out:
#      Pclass     Sex  Age  SibSp  Parch Embarked
# 10        3    male  NaN      0      0        S
# 22        1  female  NaN      0      0        S
# 29        3    male  NaN      2      0        C
# 33        3  female  NaN      1      2        S
# 36        3  female  NaN      0      0        S
# 39        3    male  NaN      0      0        S
# 41        1    male  NaN      0      0        S
# 47        3    male  NaN      0      0        Q
# 54        2    male  NaN      0      0        C
# 58        3    male  NaN      1      0        S
# 65        2  female  NaN      0      0        S
# 76        3    male  NaN      0      0        S
# 83        3    male  NaN      0      0        S
# 84        2    male  NaN      0      0        Q
# 85        3    male  NaN      1      0        C
# 88        3  female  NaN      0      0        Q
# 91        3    male  NaN      0      0        S
# 93        3    male  NaN      0      0        S
# 102       3    male  NaN      0      0        Q
# 107       3    male  NaN      0      0        Q
# 108       3    male  NaN      0      0        S
# 111       3  female  NaN      0      0        Q
# 116       3    male  NaN      0      0        C
# 121       3    male  NaN      1      0        Q
# 124       3    male  NaN      0      0        Q
# 127       3  female  NaN      2      0        Q
# 132       3  female  NaN      0      4        S
# 133       3    male  NaN      1      0        C
# 146       1    male  NaN      0      0        S
# 148       1    male  NaN      0      0        S
# ..      ...     ...  ...    ...    ...      ...
# 268       3  female  NaN      0      0        S
# 271       3    male  NaN      0      0        Q
# 273       3  female  NaN      1      0        Q
# 274       3    male  NaN      0      0        C
# 282       3  female  NaN      0      0        Q
# 286       3    male  NaN      0      0        S
# 288       3    male  NaN      0      0        C
# 289       3    male  NaN      0      0        S
# 290       1    male  NaN      0      0        S
# 292       3    male  NaN      0      0        C
# 297       3    male  NaN      2      0        C
# 301       2    male  NaN      0      0        C
# 304       3  female  NaN      0      0        Q
# 312       3    male  NaN      0      0        S
# 332       3    male  NaN      0      0        C
# 339       3    male  NaN      0      0        C
# 342       3    male  NaN      1      9        S
# 344       3    male  NaN      1      1        S
# 357       3    male  NaN      0      0        S
# 358       3    male  NaN      0      0        Q
# 365       3  female  NaN      1      9        S
# 366       3    male  NaN      1      0        C
# 380       3    male  NaN      0      0        Q
# 382       3  female  NaN      0      0        S
# 384       2    male  NaN      0      0        S
# 408       3  female  NaN      0      0        Q
# 410       3  female  NaN      0      0        Q
# 413       3    male  NaN      0      0        S
# 416       3    male  NaN      0      0        S
# 417       3    male  NaN      1      1        C
#
# [86 rows x 6 columns]

# %% [markdown]
# # Function to fill Age
# Make a function because both train and test have missing ages.

# %%
def fill_age(df):
    for s in ["male", "female"]:
            for c in [1, 2, 3]:
                truth_table = (df["Sex"] == s) & (df["Pclass"] == c)
                temp_df = df[truth_table]["Age"].dropna()
                median_age = temp_df.median()
                df.loc[(df.Age.isnull()) & (df.Sex == s) & (df.Pclass == c),"Age"] = median_age

# %%
fill_age(train2)
fill_age(test2)

# %% [markdown]
# # Correlation Plot
# Function to plot correlation map.

# %%
def show_corr(df):
    _, ax = plt.subplots(figsize=(8,6))

    # Colormap : Colors to denote correlation values
    cmap = sns.diverging_palette(250 , 10, s=68, l=40, as_cmap = True )

    # Plotting heatmap using seaborn
    sns.heatmap(df.corr(), cmap=cmap, vmin=-1, vmax=1, annot=True)

# %%
show_corr(train2)

# %% [markdown]
# # Convert features to numerical
# For now do not use one-hot encoding

# %%
num_mapper = {
                "Embarked" : {'C' : 1, 'S': 2, 'Q' : 3},
                "Sex"      : {'male' : 1, 'female': 2},
            }
train2 = train2.replace(num_mapper)
test2 = test2.replace(num_mapper)

# %%
show_corr(train2)

# %% [markdown]
# # Create X (Features) and Y (Labels)

# %%
train2_x = train2.drop(["Survived"], axis=1)
train2_x.tail(3)
# Out:
#      Pclass  Sex   Age  SibSp  Parch  Embarked
# 888       3    2  21.5      1      2         2
# 889       1    1  26.0      0      0         1
# 890       3    1  32.0      0      0         3

# %%
train2_y = train2["Survived"]
train2_y.tail()
# Out:
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, dtype: int64

# %% [markdown]
# # Testing Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

clf_rf = RandomForestClassifier(random_state = 12)
clf_rf.fit(train2_x, train2_y)
clf_rf.score(train2_x, train2_y)
# Out:
# 0.9259259259259259

# %% [markdown]
# # Function to convert predictions to appropriate csv file
# This function takes the original **test** data frame, the **predictions list**, a **filename** to save the csv file and **save** flag to determine if the csv file should be saved.

# %%
def kgl_submit_csv(df, predictions, savename = "my_predictions.csv", save=False):
    print("Number of predictions:", len(predictions))
    print("Number of passengers", len(df["PassengerId"]))
    
    kgl_df = pd.DataFrame({
        "PassengerId" : df["PassengerId"],
        "Survived" : predictions
    })
    
    if save:
        kgl_df.to_csv(savename, index=False)
    
    return kgl_df

# %%
predictions2 = clf_rf.predict(test2)

# %%
_ = kgl_submit_csv(test_df, predictions2, savename= "pred2.csv", save=True)
# Out:
# Number of predictions: 418
# Number of passengers 418

# %% [markdown]
# # Verdict
# .
# .
# .
# .
# Kaggle score = 74.641%

# %% [markdown]
# # Using Keras Fully Connected Layers

# %% [markdown]
# ## Importing Keras Modules

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# /home/lt-134/.conda/envs/kgl-forecast-keras/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## Convert DataFrame to 2d array

# %%
trainx = train2_x.values
trainx
# Out:
# array([[ 3. ,  1. , 22. ,  1. ,  0. ,  2. ],
#        [ 1. ,  2. , 38. ,  1. ,  0. ,  1. ],
#        [ 3. ,  2. , 26. ,  0. ,  0. ,  2. ],
#        ...,
#        [ 3. ,  2. , 21.5,  1. ,  2. ,  2. ],
#        [ 1. ,  1. , 26. ,  0. ,  0. ,  1. ],
#        [ 3. ,  1. , 32. ,  0. ,  0. ,  3. ]])

# %%
trainy = train2_y.values

# %% [markdown]
# ## Create a Fully Connected ANN Architecture

# %%
model = Sequential()

model.add(Dense(8, input_dim=6, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ## Assign Loss function, Optimizer and Accuracy Metrics

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ## Start the training

# %%
history_object = model.fit(trainx, trainy, epochs=40, batch_size=40, 
                           verbose=2, validation_split=0.1, 
                           shuffle=False)
# Out:
# Train on 801 samples, validate on 90 samples
# Epoch 1/40
#  - 0s - loss: 1.1488 - acc: 0.4782 - val_loss: 0.7606 - val_acc: 0.6778
# Epoch 2/40
#  - 0s - loss: 0.8105 - acc: 0.5855 - val_loss: 0.7565 - val_acc: 0.6333
# Epoch 3/40
#  - 0s - loss: 0.7899 - acc: 0.5968 - val_loss: 0.7208 - val_acc: 0.6778
# Epoch 4/40
#  - 0s - loss: 0.7655 - acc: 0.5968 - val_loss: 0.7069 - val_acc: 0.6889
# Epoch 5/40
#  - 0s - loss: 0.7497 - acc: 0.6105 - val_loss: 0.6940 - val_acc: 0.6889
# Epoch 6/40
#  - 0s - loss: 0.7334 - acc: 0.6105 - val_loss: 0.6804 - val_acc: 0.6778
# Epoch 7/40
#  - 0s - loss: 0.7182 - acc: 0.6067 - val_loss: 0.6678 - val_acc: 0.6778
# Epoch 8/40
#  - 0s - loss: 0.7038 - acc: 0.6067 - val_loss: 0.6555 - val_acc: 0.6556
# Epoch 9/40
#  - 0s - loss: 0.6902 - acc: 0.6117 - val_loss: 0.6441 - val_acc: 0.6444
# Epoch 10/40
#  - 0s - loss: 0.6771 - acc: 0.6230 - val_loss: 0.6310 - val_acc: 0.6444
# Epoch 11/40
#  - 0s - loss: 0.6638 - acc: 0.6230 - val_loss: 0.6183 - val_acc: 0.6556
# Epoch 12/40
#  - 0s - loss: 0.6504 - acc: 0.6292 - val_loss: 0.6019 - val_acc: 0.6556
# Epoch 13/40
#  - 0s - loss: 0.6373 - acc: 0.6417 - val_loss: 0.5866 - val_acc: 0.6667
# Epoch 14/40
#  - 0s - loss: 0.6259 - acc: 0.6517 - val_loss: 0.5729 - val_acc: 0.6889
# Epoch 15/40
#  - 0s - loss: 0.6156 - acc: 0.6667 - val_loss: 0.5611 - val_acc: 0.7000
# Epoch 16/40
#  - 0s - loss: 0.6065 - acc: 0.6729 - val_loss: 0.5511 - val_acc: 0.7222
# Epoch 17/40
#  - 0s - loss: 0.5981 - acc: 0.6866 - val_loss: 0.5413 - val_acc: 0.7556
# Epoch 18/40
#  - 0s - loss: 0.5894 - acc: 0.7041 - val_loss: 0.5333 - val_acc: 0.7667
# Epoch 19/40
#  - 0s - loss: 0.5805 - acc: 0.7116 - val_loss: 0.5271 - val_acc: 0.7667
# Epoch 20/40
#  - 0s - loss: 0.5714 - acc: 0.7253 - val_loss: 0.5208 - val_acc: 0.7667
# Epoch 21/40
#  - 0s - loss: 0.5632 - acc: 0.7353 - val_loss: 0.5160 - val_acc: 0.7667
# Epoch 22/40
#  - 0s - loss: 0.5565 - acc: 0.7441 - val_loss: 0.5103 - val_acc: 0.8000
# Epoch 23/40
#  - 0s - loss: 0.5488 - acc: 0.7503 - val_loss: 0.5051 - val_acc: 0.8000
# Epoch 24/40
#  - 0s - loss: 0.5376 - acc: 0.7528 - val_loss: 0.4963 - val_acc: 0.8333
# Epoch 25/40
#  - 0s - loss: 0.5298 - acc: 0.7628 - val_loss: 0.4923 - val_acc: 0.8333
# Epoch 26/40
#  - 0s - loss: 0.5253 - acc: 0.7653 - val_loss: 0.4880 - val_acc: 0.8444
# Epoch 27/40
#  - 0s - loss: 0.5203 - acc: 0.7653 - val_loss: 0.4834 - val_acc: 0.8556
# Epoch 28/40
#  - 0s - loss: 0.5160 - acc: 0.7690 - val_loss: 0.4795 - val_acc: 0.8556
# Epoch 29/40
#  - 0s - loss: 0.5120 - acc: 0.7715 - val_loss: 0.4759 - val_acc: 0.8556
# Epoch 30/40
#  - 0s - loss: 0.5081 - acc: 0.7740 - val_loss: 0.4720 - val_acc: 0.8556
# Epoch 31/40
#  - 0s - loss: 0.5042 - acc: 0.7790 - val_loss: 0.4676 - val_acc: 0.8667
# Epoch 32/40
#  - 0s - loss: 0.5001 - acc: 0.7840 - val_loss: 0.4629 - val_acc: 0.8778
# Epoch 33/40
#  - 0s - loss: 0.4966 - acc: 0.7840 - val_loss: 0.4579 - val_acc: 0.8778
# Epoch 34/40
#  - 0s - loss: 0.4922 - acc: 0.7865 - val_loss: 0.4552 - val_acc: 0.8778
# Epoch 35/40
#  - 0s - loss: 0.4875 - acc: 0.7978 - val_loss: 0.4534 - val_acc: 0.8667
# Epoch 36/40
#  - 0s - loss: 0.4840 - acc: 0.7953 - val_loss: 0.4510 - val_acc: 0.8667
# Epoch 37/40
#  - 0s - loss: 0.4807 - acc: 0.7990 - val_loss: 0.4480 - val_acc: 0.8556
# Epoch 38/40
#  - 0s - loss: 0.4775 - acc: 0.8015 - val_loss: 0.4453 - val_acc: 0.8556
# Epoch 39/40
#  - 0s - loss: 0.4748 - acc: 0.8027 - val_loss: 0.4426 - val_acc: 0.8556
# Epoch 40/40
#  - 0s - loss: 0.4722 - acc: 0.8052 - val_loss: 0.4402 - val_acc: 0.8556

# %% [markdown]
# ## Function to visualize training loss

# %%
def visualize_loss(history_obj, show=False, save=True, x=10, y=10):

    plt.figure(figsize=(x, y))
    plt.plot(history_obj.history['loss'])
    plt.plot(history_obj.history['val_loss'])
    plt.title(' Model Loss Visualization')
    plt.ylabel('Mean Squared Error Loss')
    plt.xlabel('Epoch')
    plt.legend(['training set', 'validation set'], loc='upper right')
    plt.grid()

# %%
visualize_loss(history_object)

# %% [markdown]
# ## Function to save Keras predictions

# %%
def kgl_submit_csv_keras(df, predictions, savename = "my_predictions.csv", save=False):
    print("Number of predictions:", len(predictions))
    print("Number of passengers", len(df["PassengerId"]))
    
    kgl_df = pd.DataFrame({
        "PassengerId" : df["PassengerId"],
        "Survived" : predictions.reshape(-1)
    })
    
    kgl_df.loc[kgl_df["Survived"]>=0.5, "Survived"]= 1
    kgl_df.loc[kgl_df["Survived"]<0.5, "Survived"]= 0
    kgl_df["Survived"] = np.array(kgl_df["Survived"]).astype(int)
    if save:
        kgl_df.to_csv(savename, index=False)
    
    return kgl_df

# %%
predictions_k = model.predict(test2.values)

# %%
kgl_submit_csv_keras(test_df, predictions_k, savename="pred_keras.csv", save=True)
# Out:
# Number of predictions: 418
# Number of passengers 418
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# 5            897         0
# 6            898         0
# 7            899         0
# 8            900         0
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         0
# 19           911         0
# 20           912         0
# 21           913         1
# 22           914         1
# 23           915         1
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# 390         1282         1
# 391         1283         1
# 392         1284         1
# 393         1285         0
# 394         1286         0
# 395         1287         1
# 396         1288         0
# 397         1289         1
# 398         1290         0
# 399         1291         0
# 400         1292         1
# 401         1293         0
# 402         1294         1
# 403         1295         0
# 404         1296         1
# 405         1297         0
# 406         1298         0
# 407         1299         0
# 408         1300         1
# 409         1301         1
# 410         1302         1
# 411         1303         1
# 412         1304         0
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %% [markdown]
# # Verdict
# .
# .
# .
# .
# .
# Kaggle score = 76.076 %
